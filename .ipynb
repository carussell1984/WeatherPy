corner brook', 'palora', 'hibbing', 'tupelo', 'angra dos reis', 'francisco beltrao', 'calabozo', 'stuttgart', 'san matias', 'belle fourche', 'vreed en hoop', 'lethem', 'ipixuna', 'campos', 'ayolas', 'san ramon', 'samana', 'thunder bay', 'melville', 'dryden', 'gloversville', 'marienburg', 'luziania', 'sioux lookout', 'guadalupe', 'new richmond', 'redlands', 'zachary', 'la ronge', 'huarmey', 'meridian', 'castelo do piaui', 'cururupu', 'valcourt', 'devils lake', 'warrington', 'river falls', 'itaituba', 'shelburne', 'lewisporte', 'ancud', 'rio gallegos', 'vilhena', 'rapid city', 'celendin', 'fonte boa', 'mosquera', 'mabaruma', 'hannibal', 'tome-acu', 'saint anthony', 'capreol', 'adolfo lopez mateos', 'constitucion', 'warman', 'arraial do cabo', 'betsiamites', 'talcahuano', 'san fernando', 'pocone', 'waterford', 'japura', 'ponta do sol', 'dolores', 'the valley', 'rio grande', 'paamiut', 'dunmore town', 'pierre', 'san carlos de bariloche', 'araras', 'varadero', 'flin flon', 'santa barbara', 'lucea', 'channel-port aux basques', 'sao lourenco do sul', 'saucillo', 'acajutla', 'imbituba', 'virginia beach', 'aguadilla', 'inirida', 'guerrero', 'guadalupe y calvo', 'trinidad', 'ocampo', 'corinto', 'tutoia', 'hornepayne', 'maldonado', 'onalaska', 'champoton', 'tucurui', 'manta', 'fenelon falls', 'san pedro de macoris', 'bella union',  ...

# %%
cities_2 = []

for city in cities:
    if " " in city:
        city2 = city.replace(" ", "+")
        cities_2.append(city2)
    else:
        cities_2.append(city)

print(cities_2)
# Out:
# ['sept-iles', 'pangnirtung', 'saint+george', 'coari', 'castro', 'thompson', 'bathsheba', 'punta+arenas', 'bataipora', 'mar+del+plata', 'torbay', 'litoral+del+san+juan', 'regeneracao', 'deep+river', 'cartagena', 'san+jeronimo+de+tunan', 'glenwood+springs', 'chicama', 'marcona', 'puerto+ayora', 'dulce+nombre+de+culmi', 'yellowknife', 'san+andres', 'porto+belo', 'port+hawkesbury', 'ushuaia', 'comodoro+rivadavia', 'mazatlan', 'cartagena+del+chaira', 'puerto+plata', 'athens', 'la+libertad', 'topolobampo', 'lebu', 'rawson', 'ixtapa', 'iqaluit', 'tapaua', 'narsaq', 'attawapiskat', 'general+roca', 'san+angelo', 'san+jose', 'campos+altos', 'avare', 'viesca', 'freeport', 'sao+geraldo+do+araguaia', 'qaanaaq', 'suamico', 'council+bluffs', 'palmares+do+sul', 'upernavik', 'coquimbo', 'arica', 'rikitea', 'cayenne', 'cidreira', 'paz+de+ariporo', 'amapa', 'codrington', 'coxim', 'santa+cruz', 'isla+aguada', 'general+jose+eduvigis+diaz', 'cassilandia', 'nuuk', 'planaltina', 'puerto+el+triunfo', 'pisco', 'tecoanapa', 'taltal', 'laguna', 'gimli', 'ilulissat', 'tucuma', 'antofagasta', 'san+juan', 'high+rock', 'careiro+da+varzea', 'dolbeau', 'burica', 'cumana', 'coihaique', 'tocopilla', 'barranca', 'rapid+valley', 'upata', 'caiaponia', '
...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "&units=imperial"

#create dictionary lists
city_name = []
temperature = []
latitude = []
humidity_perc = []
cloudiness_perc = []
wind_speed = []
time = []
timezone = []
longitude = []



count = 0


for city in cities_2:
    query_url = (url + "appid=" + api_key + units + "&q=")
    count = count + 1
    print(f"Record {count} is processing | {city}")
           
    try:     
        city_weather_requests = requests.get(query_url+city).json()
        city_name.append(city)
    except AttributeError: 
        print("city is missing...")
        pass
    
    try:
        if city_weather_requests["main"]["temp"] is not None:
            temperature.append(city_weather_requests["main"]["temp"])
    except: 
            temperature.append("none")
            
    try: 
        if city_weather_requests["coord"]["lat"] is not None:
            latitude.append(city_weather_requests["coord"]["lat"])
    except: 
        latitude.append("none")
            
    try: 
        if city_weather_requests["main"]["humidity"] is not None:
            humidity_perc.append(city_weather_requests["main"]["humidity"])
    except: 
        humidity_perc.append("none")
        
    try: 
        if city_weather_requests["clouds"]["all"] is not None:
            cloudiness_perc.append(city_weather_requests["clouds"]["all"])
    except:
        cloudiness_perc.append("none")
        
    try: 
        if city_weather_requests["wind"]["speed"] is not None:
            wind_speed.append(city_weather_requests["wind"]["speed"])
    except: 
        wind_speed.append("none")
        
    try: 
        if city_weather_requests["coord"]["lon"] is not None:
            longitude.append(city_weather_requests["coord"]["lon"])
    except: 
        longitude.append("none")
        
    try: 
        if city_weather_requests["wind"]["speed"] is not None:
            timezone.append(city_weather_requests["wind"]["speed"])
    except: 
        timezone.append("none")
            
    try: 
        if city_weather_requests["dt"] is not None:
            time.append(city_weather_requests["dt"])
    except: 
        time.append("none")
# Out:
# Record 1 is processing | sept-iles
# Record 2 is processing | pangnirtung
# Record 3 is processing | saint+george
# Record 4 is processing | coari
# Record 5 is processing | castro
# Record 6 is processing | thompson
# Record 7 is processing | bathsheba
# Record 8 is processing | punta+arenas
# Record 9 is processing | bataipora
# Record 10 is processing | mar+del+plata
# Record 11 is processing | torbay
# Record 12 is processing | litoral+del+san+juan
# Record 13 is processing | regeneracao
# Record 14 is processing | deep+river
# Record 15 is processing | cartagena
# Record 16 is processing | san+jeronimo+de+tunan
# Record 17 is processing | glenwood+springs
# Record 18 is processing | chicama
# Record 19 is processing | marcona
# Record 20 is processing | puerto+ayora
# Record 21 is processing | dulce+nombre+de+culmi
# Record 22 is processing | yellowknife
# Record 23 is processing | san+andres
# Record 24 is processing | porto+belo
# Record 25 is processing | port+hawkesbury
# Record 26 is processing | ushuaia
# Record 27 is processing | comodoro+rivadavia
# Record 28 is processing | mazatlan
# Record 29 is processing | cartagena+del+chaira
# Record 30 is processing | puerto+plata
# Record 31 is processing | athens
# Record 32 is processing | la+libertad
# Record 33 is processing | topolobampo
# Record 34 is processing | lebu
# Record 35 is processing | rawson
# Record 36 is processing | ixtapa
# Record 37 is processing | iqaluit
# Record 38 is processing | tapaua
# Record 39 is processing | narsaq
# Record 40 is processing | attawapiskat
# Record 41 is processing | general+roca
# Record 42 is processing | san+angelo
# Record 43 is processing | san+jose
# Record 44 is processing | campos+altos
# Record 45 is processing | avare
# Record 46 is processing | viesca
# Record 47 is processing | freeport
# Record 48 is processing | sao+geraldo+do+araguaia
# Record 49 is processing | qaanaaq
# Record 50 is processing | suamico
# Record 51 is processing | council+bluffs
# Record 52 is processing | palmares+do+sul
# Record 53 is processing | upernavik
# Record 54 is processing | coquimbo
# Record 55 is processing | arica
# Record 56 is processing | rikitea
# Record 57 is processing | cayenne
# Record 58 is processing | cidreira
# Record 59 is processing | paz+de+ariporo
# Record 60 is processing | amapa
# Record 61 is processing | codrington
# Record 62 is processing | coxim
# Record 63 is processing | santa+cruz
# Record 64 is processing | isla+aguada
# Record 65 is processing | general+jose+eduvigis+diaz
# Record 66 is processing | cassilandia
# Record 67 is processing | nuuk
# Record 68 is processing | planaltina
# Record 69 is processing | puerto+el+triunfo
# Record 70 is processing | pisco
# Record 71 is processing | tecoanapa
# Record 72 is processing | taltal
# Record 73 is processing | laguna
# Record 74 is processing | gimli
# Record 75 is processing | ilulissat
# Record 76 is processing | tucuma
# Record 77 is processing | antofagasta
# Record 78 is processing | san+juan
# Record 79 is processing | high+rock
# Record 80 is processing | careiro+da+varzea
# Record 81 is processing | dolbeau
# Record 82 is processing | burica
# Record 83 is processing | cumana
# Record 84 is processing | coihaique
# Record 85 is processing | tocopilla
# Record 86 is processing | barranca
# Record 87 is processing | rapid+valley
# Record 88 is processing | upata
# Record 89 is processing | caiaponia
# Record 90 is processing | puerto+leguizamo
# Record 91 is processing | kourou
# Record 92 is processing | galveston
# Record 93 is processing | maniitsoq
# Record 94 is processing | pinawa
# Record 95 is processing | sayabec
# Record 96 is processing | san+cristobal
# Record 97 is processing | celestun
# Record 98 is processing | ribeira+grande
# Record 99 is processing | tomatlan
# Record 100 is processing | chapais
# Record 101 is processing | rolim+de+moura
# Record 102 is processing | acapulco
# Record 103 is processing | sechura
# Record 104 is processing | havre
# Record 105 is processing | boa+vista
# Record 106 is processing | saint-francois
# Record 107 is processing | potrerillos
# Record 108 is processing | tres+arroyos
# Record 109 is processing | liverpool
# Record 110 is processing | nanortalik
# Record 111 is processing | longlac
# Record 112 is processing | road+town
# Record 113 is processing | pimentel
# Record 114 is processing | pointe-noire
# Record 115 is processing | marshfield
# Record 116 is processing | diamantino
# Record 117 is processing | nicoya
# Record 118 is processing | laguna+de+perlas
# Record 119 is processing | sulphur
# Record 120 is processing | iracoubo
# Record 121 is processing | riachao+das+neves
# Record 122 is processing | scarborough
# Record 123 is processing | salinas
# Record 124 is processing | aripuana
# Record 125 is processing | miami
# Record 126 is processing | el+estor
# Record 127 is processing | hualmay
# Record 128 is processing | clyde+river
# Record 129 is processing | santiago+de+puringla
# Record 130 is processing | port+washington
# Record 131 is processing | oranjestad
# Record 132 is processing | mayor+pablo+lagerenza
# Record 133 is processing | viedma
# Record 134 is processing | illapel
# Record 135 is processing | bridgetown
# Record 136 is processing | rocha
# Record 137 is processing | chalmette
# Record 138 is processing | santa+fe
# Record 139 is processing | sinnamary
# Record 140 is processing | puerto+narino
# Record 141 is processing | totness
# Record 142 is processing | la+palma
# Record 143 is processing | middle+island
# Record 144 is processing | puerto+madryn
# Record 145 is processing | saint-augustin
# Record 146 is processing | carutapera
# Record 147 is processing | cienfuegos
# Record 148 is processing | langham
# Record 149 is processing | the+pas
# Record 150 is processing | bonavista
# Record 151 is processing | marica
# Record 152 is processing | effingham
# Record 153 is processing | ixtlahuacan+del+rio
# Record 154 is processing | sao+felix+do+xingu
# Record 155 is processing | batesville
# Record 156 is processing | vallenar
# Record 157 is processing | mapiripan
# Record 158 is processing | tasiilaq
# Record 159 is processing | tallahassee
# Record 160 is processing | chuy
# Record 161 is processing | hamilton
# Record 162 is processing | saint-pierre
# Record 163 is processing | gouyave
# Record 164 is processing | trelew
# Record 165 is processing | steamboat+springs
# Record 166 is processing | saint+augustine
# Record 167 is processing | formoso+do+araguaia
# Record 168 is processing | manaure
# Record 169 is processing | lac+du+bonnet
# Record 170 is processing | kangaatsiaq
# Record 171 is processing | sydney+mines
# Record 172 is processing | cockburn+town
# Record 173 is processing | eirunepe
# Record 174 is processing | marystown
# Record 175 is processing | alta+gracia
# Record 176 is processing | fort+wellington
# Record 177 is processing | san+jose+de+guanipa
# Record 178 is processing | nantucket
# Record 179 is processing | borba
# Record 180 is processing | camana
# Record 181 is processing | la+belleza
# Record 182 is processing | cardoso
# Record 183 is processing | jeremie
# Record 184 is processing | emporia
# Record 185 is processing | remedios
# Record 186 is processing | saint-jean-port-joli
# Record 187 is processing | santa+cruz+del+sur
# Record 188 is processing | puerto+vallarta
# Record 189 is processing | almeirim
# Record 190 is processing | corner+brook
# Record 191 is processing | palora
# Record 192 is processing | hibbing
# Record 193 is processing | tupelo
# Record 194 is processing | angra+dos+reis
# Record 195 is processing | francisco+beltrao
# Record 196 is processing | calabozo
# Record 197 is processing | stuttgart
# Record 198 is processing | san+matias
# Record 199 is processing | belle+fourche
# Record 200 is processing | vreed+en+hoop
# Record 201 is processing | lethem
# Record 202 is processing | ipixuna
# Record 203 is processing | campos
# Record 204 is processing | ayolas
# Record 205 is processing | san+ramon
# Record 206 is processing | samana
# Record 207 is processing | thunder+bay
# Record 208 is processing | melville
# Record 209 is processing | dryden
# Record 210 is processing | gloversville
# Record 211 is processing | marienburg
# Record 212 is processing | luziania
# Record 213 is processing | sioux+lookout
# Record 214 is processing | guadalupe
# Record 215 is processing | new+richmond
# Record 216 is processing | redlands
# Record 217 is processing | zachary
# Record 218 is processing | la+ronge
# Record 219 is processing | huarmey
# Record 220 is processing | meridian
# Record 221 is processing | castelo+do+piaui
# Record 222 is processing | cururupu
# Record 223 is processing | valcourt
# Record 224 is processing | devils+lake
# Record 225 is processing | warrington
# Record 226 is processing | river+falls
# Record 227 is processing | itaituba
# Record 228 is processing | shelburne
# Record 229 is processing | lewisporte
# Record 230 is processing | ancud
# Record 231 is processing | rio+gallegos
# Record 232 is processing | vilhena
# Record 233 is processing | rapid+city
# Record 234 is processing | celendin
# Record 235 is processing | fonte+boa
# Record 236 is processing | mosquera
# Record 237 is processing | mabaruma
# Record 238 is processing | hannibal
# Record 239 is processing | tome-acu
# Record 240 is processing | saint+anthony
# Record 241 is processing | capreol
# Record 242 is processing | adolfo+lopez+mateos
# Record 243 is processing | constitucion
# Record 244 is processing | warman
# Record 245 is processing | arraial+do+cabo
# Record 246 is processing | betsiamites
# Record 247 is processing | talcahuano
# Record 248 is processing | san+fernando
# Record 249 is processing | pocone
# Record 250 is processing | waterford
# Record 251 is processing | japura
# Record 252 is processing | ponta+do+sol
# Record 253 is processing | dolores
# Record 254 is processing | the+valley
# Record 255 is processing | rio+grande
# Record 256 is processing | paamiut
# Record 257 is processing | dunmore+town
# Record 258 is processing | pierre
# Record 259 is processing | san+carlos+de+bariloche
# Record 260 is processing | araras
# Record 261 is processing | varadero
# Record 262 is processing | flin+flon
# Record 263 is processing | santa+barbara
# Record 264 is processing | lucea
# Record 265 is processing | channel-port+aux+basques
# Record 266 is processing | sao+lourenco+do+sul
# Record 267 is processing | saucillo
# Record 268 is processing | acajutla
# Record 269 is processing | imbituba
# Record 270 is processing | virginia+beach
# Record 271 is processing | aguadilla
# Record 272 is processing | inirida
# Record 273 is processing | guerrero
# Record 274 is processing | guadalupe+y+calvo
# Record 275 is processing | trinidad
# Record 276 is processing | ocampo
# Record 277 is processing | corinto
# Record 278 is processing | tutoia
# Record 279 is processing | hornepayne
# Record 280 is processing | maldonado
# Record 281 is processing | onalaska
# Record 282 is processing | champoton
# Record 283 is processing | tucurui
# Record 284 is processing | manta
# Record 285 is processing | fenelon+falls
# Record 286 is processing | san+pedro+de+macoris
# Record 287 is processing | bella+union
# Record 288 is processing | puerto+escondido
# Record 289 is processing | clinton
# Record 290 is processing | havelock
# Record 291 is processing | port-cartier
# Record 292 is processing | grand+centre
# Record 293 is processing | puerto+ayacucho
# Record 294 is processing | san+luis
# Record 295 is processing | girua
# Record 296 is processing | grajau
# Record 297 is processing | rio+branco
# Record 298 is processing | ailigandi
# Record 299 is processing | nova+olimpia
# Record 300 is processing | rincon
# Record 301 is processing | aguas+vermelhas
# Record 302 is processing | humboldt
# Record 303 is processing | barcelos
# Record 304 is processing | florianopolis
# Record 305 is processing | gillette
# Record 306 is processing | parnarama
# Record 307 is processing | paita
# Record 308 is processing | oistins
# Record 309 is processing | williamsport
# Record 310 is processing | yeehaw+junction
# Record 311 is processing | louisbourg
# Record 312 is processing | ilhabela
# Record 313 is processing | conway
# Record 314 is processing | jacareacanga
# Record 315 is processing | merrill
# Record 316 is processing | saint-georges
# Record 317 is processing | laurel
# Record 318 is processing | sisimiut
# Record 319 is processing | jujuy
# Record 320 is processing | asheboro
# Record 321 is processing | estelle
# Record 322 is processing | necochea
# Record 323 is processing | san+juan+nepomuceno
# Record 324 is processing | iralaya
# Record 325 is processing | ibirite
# Record 326 is processing | filadelfia
# Record 327 is processing | progreso
# Record 328 is processing | iquique
# Record 329 is processing | miles+city
# Record 330 is processing | kirksville
# Record 331 is processing | sao+simao
# Record 332 is processing | foam+lake
# Record 333 is processing | elliot+lake
# Record 334 is processing | qasigiannguit
# Record 335 is processing | scottsboro
# Record 336 is processing | loanda
# Record 337 is processing | pucallpa
# Record 338 is processing | mangaratiba
# Record 339 is processing | saquarema
# Record 340 is processing | marsh+harbour
# Record 341 is processing | acari
# Record 342 is processing | baiao
# Record 343 is processing | old+town
# Record 344 is processing | camopi
# Record 345 is processing | carthage
# Record 346 is processing | bull+savanna
# Record 347 is processing | lima
# Record 348 is processing | alice+town
# Record 349 is processing | gallup
# Record 350 is processing | manicore
# Record 351 is processing | charleston
# Record 352 is processing | lincoln
# Record 353 is processing | virden
# Record 354 is processing | santo+domingo
# Record 355 is processing | lazaro+cardenas
# Record 356 is processing | mana
# Record 357 is processing | panaba
# Record 358 is processing | glendive
# Record 359 is processing | general+pico
# Record 360 is processing | la+orilla
# Record 361 is processing | big+rapids
# Record 362 is processing | cadereyta
# Record 363 is processing | puerto+maldonado
# Record 364 is processing | ananas
# Record 365 is processing | presidencia+roque+saenz+pena
# Record 366 is processing | bartica
# Record 367 is processing | lexington
# Record 368 is processing | boca+do+acre
# Record 369 is processing | guanica
# Record 370 is processing | san+pedro+ayampuc
# Record 371 is processing | iowa+city
# Record 372 is processing | neuquen
# Record 373 is processing | shelbyville
# Record 374 is processing | uyuni
# Record 375 is processing | palmeira
# Record 376 is processing | salinopolis
# Record 377 is processing | muisne
# Record 378 is processing | canton
# Record 379 is processing | beaver+dam
# Record 380 is processing | rioja
# Record 381 is processing | parrita
# Record 382 is processing | alta+floresta
# Record 383 is processing | le+moule
# Record 384 is processing | bom+jesus+da+lapa
# Record 385 is processing | portobelo
# Record 386 is processing | key+biscayne
# Record 387 is processing | san+miguel
# Record 388 is processing | atlantic+city
# Record 389 is processing | glens+falls
# Record 390 is processing | champerico
# Record 391 is processing | pontes+e+lacerda
# Record 392 is processing | bowling+green
# Record 393 is processing | santa+isabel+do+rio+negro
# Record 394 is processing | pedasi
# Record 395 is processing | talara
# Record 396 is processing | andes
# Record 397 is processing | carbonear
# Record 398 is processing | palotina
# Record 399 is processing | malacacheta
# Record 400 is processing | qaqortoq
# Record 401 is processing | rio+cuarto
# Record 402 is processing | puquio
# Record 403 is processing | lumsden
# Record 404 is processing | pauini
# Record 405 is processing | matamoros
# Record 406 is processing | coffeyville
# Record 407 is processing | normandin
# Record 408 is processing | cabo+san+lucas
# Record 409 is processing | meadow+lake
# Record 410 is processing | tecpan
# Record 411 is processing | venado+tuerto
# Record 412 is processing | pedernales
# Record 413 is processing | puerto+suarez
# Record 414 is processing | san+clemente
# Record 415 is processing | altamira
# Record 416 is processing | julio+de+castilhos
# Record 417 is processing | perry
# Record 418 is processing | vicuna
# Record 419 is processing | pozo+colorado
# Record 420 is processing | digby
# Record 421 is processing | poplar+bluff
# Record 422 is processing | macusani
# Record 423 is processing | valparaiso
# Record 424 is processing | hatillo
# Record 425 is processing | mount+pleasant
# Record 426 is processing | staunton
# Record 427 is processing | mazamari
# Record 428 is processing | lamar
# Record 429 is processing | pucara
# Record 430 is processing | atocha
# Record 431 is processing | barra+do+garcas
# Record 432 is processing | shaunavon
# Record 433 is processing | santa+rosa
# Record 434 is processing | ahumada
# Record 435 is processing | sao+joaquim
# Record 436 is processing | tena
# Record 437 is processing | cacu
# Record 438 is processing | natchez
# Record 439 is processing | dauphin
# Record 440 is processing | jaguaruna
# Record 441 is processing | humaita
# Record 442 is processing | iquitos
# Record 443 is processing | tefe
# Record 444 is processing | el+reno
# Record 445 is processing | gravelbourg
# Record 446 is processing | crab+hill
# Record 447 is processing | lively
# Record 448 is processing | causapscal
# Record 449 is processing | alto+araguaia
# Record 450 is processing | washington
# Record 451 is processing | sao+sebastiao+do+cai
# Record 452 is processing | caronport
# Record 453 is processing | west+bay
# Record 454 is processing | hopatcong
# Record 455 is processing | contamana
# Record 456 is processing | miquelon
# Record 457 is processing | la+peca
# Record 458 is processing | la+ligua
# Record 459 is processing | poptun
# Record 460 is processing | port+maria
# Record 461 is processing | chilca
# Record 462 is processing | ovalle
# Record 463 is processing | wausau
# Record 464 is processing | seaford
# Record 465 is processing | canete
# Record 466 is processing | miramar
# Record 467 is processing | urucara
# Record 468 is processing | tamiahua
# Record 469 is processing | maraba
# Record 470 is processing | tubuala
# Record 471 is processing | jamestown
# Record 472 is processing | winfield
# Record 473 is processing | monte+patria
# Record 474 is processing | mineiros
# Record 475 is processing | santa+helena
# Record 476 is processing | havre-saint-pierre
# Record 477 is processing | marinette
# Record 478 is processing | cap-aux-meules
# Record 479 is processing | tayoltita
# Record 480 is processing | moultonborough
# Record 481 is processing | assiniboia
# Record 482 is processing | grand+junction
# Record 483 is processing | camargo
# Record 484 is processing | villarrica
# Record 485 is processing | horconcitos
# Record 486 is processing | orangeburg
# Record 487 is processing | port+lavaca
# Record 488 is processing | miracema+do+tocantins
# Record 489 is processing | mastic+beach
# Record 490 is processing | mitu
# Record 491 is processing | paso+de+los+toros
# Record 492 is processing | newton
# Record 493 is processing | sao+gabriel
# Record 494 is processing | new+waterford
# Record 495 is processing | moose+factory
# Record 496 is processing | sacama
# Record 497 is processing | eldorado
# Record 498 is processing | rio+verde+de+mato+grosso
# Record 499 is processing | ocos
# Record 500 is processing | natalio
# Record 501 is processing | malartic
# Record 502 is processing | boa+esperanca
# Record 503 is processing | calama
# Record 504 is processing | eston
# Record 505 is processing | dibulla
# Record 506 is processing | bar+harbor
# Record 507 is processing | springfield
# Record 508 is processing | san+juan+del+sur
# Record 509 is processing | san+ignacio
# Record 510 is processing | san+carlos
# Record 511 is processing | coihueco
# Record 512 is processing | simplicio+mendes
# Record 513 is processing | rock+springs
# Record 514 is processing | santiago+del+estero
# Record 515 is processing | caceres
# Record 516 is processing | monroe
# Record 517 is processing | kralendijk
# Record 518 is processing | cuencame
# Record 519 is processing | vidalia
# Record 520 is processing | florestopolis
# Record 521 is processing | morgan+city
# Record 522 is processing | whitewater
# Record 523 is processing | traverse+city
# Record 524 is processing | bacalar
# Record 525 is processing | mulchen
# Record 526 is processing | houma
# Record 527 is processing | sao+raimundo+nonato
# Record 528 is processing | ciudad+bolivar
# Record 529 is processing | morros

# %%
print(len(city_name))
print(len(temperature))
print(len(latitude))
print(len(humidity_perc))
print(len(cloudiness_perc))
print(len(wind_speed))
print(len(time))
print(len(timezone))
print(len(longitude))
# Out:
# 529
# 529
# 529
# 529
# 529
# 529
# 529
# 529
# 529

# %%
print(city_name)
print(temperature)
print(latitude)
print(humidity_perc)
print(cloudiness_perc)
print(wind_speed)
print(time)
print(timezone)
print(longitude)
# Out:
# ['sept-iles', 'pangnirtung', 'saint+george', 'coari', 'castro', 'thompson', 'bathsheba', 'punta+arenas', 'bataipora', 'mar+del+plata', 'torbay', 'litoral+del+san+juan', 'regeneracao', 'deep+river', 'cartagena', 'san+jeronimo+de+tunan', 'glenwood+springs', 'chicama', 'marcona', 'puerto+ayora', 'dulce+nombre+de+culmi', 'yellowknife', 'san+andres', 'porto+belo', 'port+hawkesbury', 'ushuaia', 'comodoro+rivadavia', 'mazatlan', 'cartagena+del+chaira', 'puerto+plata', 'athens', 'la+libertad', 'topolobampo', 'lebu', 'rawson', 'ixtapa', 'iqaluit', 'tapaua', 'narsaq', 'attawapiskat', 'general+roca', 'san+angelo', 'san+jose', 'campos+altos', 'avare', 'viesca', 'freeport', 'sao+geraldo+do+araguaia', 'qaanaaq', 'suamico', 'council+bluffs', 'palmares+do+sul', 'upernavik', 'coquimbo', 'arica', 'rikitea', 'cayenne', 'cidreira', 'paz+de+ariporo', 'amapa', 'codrington', 'coxim', 'santa+cruz', 'isla+aguada', 'general+jose+eduvigis+diaz', 'cassilandia', 'nuuk', 'planaltina', 'puerto+el+triunfo', 'pisco', 'tecoanapa', 'taltal', 'laguna', 'gimli', 'ilulissat', 'tucuma', 'antofagasta', 'san+juan', 'high+rock', 'careiro+da+varzea', 'dolbeau', 'burica', 'cumana', 'coihaique', 'tocopilla', 'barranca', 'rapid+valley', 'upata', 'caiaponia', 'puerto+leguizamo', 'kourou', 'galveston', 'maniitsoq', 'pinawa', 'sayabec', 'san+cristobal', 'celestun', 'ribeira+grande', 'tomatlan', 'chapais', 'rolim+de+moura', 'acapulco', 'sechura', 'havre', 'boa+vista', 'saint-francois', 'potrerillos', 'tres+arroyos', 'liverpool', 'nanortalik', 'longlac', 'road+town', 'pimentel', 'pointe-noire', 'marshfield', 'diamantino', 'nicoya', 'laguna+de+perlas', 'sulphur', 'iracoubo', 'riachao+das+neves', 'scarborough', 'salinas', 'aripuana', 'miami', 'el+estor', 'hualmay', 'clyde+river', 'santiago+de+puringla', 'port+washington', 'oranjestad', 'mayor+pablo+lagerenza', 'viedma', 'illapel', 'bridgetown', 'rocha', 'chalmette', 'santa+fe', 'sinnamary', 'puerto+narino', 'totness', 'la+palma', 'middle+island', 'puerto+madryn', 'saint-augustin', 'carutapera', 'cienfuegos', 'langham', 'the+pas', 'bonavista', 'marica', 'effingham', 'ixtlahuacan+del+rio', 'sao+felix+
-44.06, -60.04, -56.22, -70.14, -105.84, -92.58, -47.55, -103.53, -82.65, -51.19, -86.03, -53.14, -74.54, -44.04, -42.51, -77.06, -36.64, -49.67, 14.42, -52.33, -94.34, -77.59, -77.04, -79.3, -108.74, -61.3, -81.63, -0.54, -100.93, -69.94, -105.62, 20.24, -88.27, -104.71, -63.75, -102.23, -85.48, -99.98, -69.19, -71.96, -60.44, -58.62, -84.5, -67.39, -66.91, -90.45, -91.53, -68.06, -88.79, -66.82, -50, -47.36, -80.02, -81.38, -88.84, -77.17, -84.33, -56.08, -61.35, -43.41, -79.65, -80.16, -58.72, 'none', -73.64, -93.6, -59.33, -86.44, -65.02, -80.03, -81.27, -75.88, -53.24, -53.84, -42.08, -46.03, -64.35, -74.12, -104.86, -67, -97.51, -95.62, -72.53, -109.91, -108.44, -90.99, -61.97, -80.05, -57.8, -117.61, -52.21, -53.68, -83.58, 'none', -58.8, -65.76, -90.39, -70.43, -87.06, -66.83, -94.97, -79.07, -74.53, -102.62, -64.2, -78.6, -52.26, -108.41, -64.29, 'none', -49.93, -77.82, -51.13, -91.4, -100.04, -49.03, -65.37, -73.25, -64.71, -97.96, -106.56, 'none', -99.18, -67.23, -53.22, -77.04, -51.38, -105.81, -2.76, -74.66, -75.01, -56.38, -78.44, -71.23, -89.42, -76.89, -72.34, -71.2, -89.63, 0.1, 9.49, -84.73, -57.76, -97.45, -49.1, -79.03, 138.6, -87.28, -70.96, -52.55, -45.3, -63.6, -87.63, -61.86, -105.93, -71.4, -105.99, -108.55, -105.17, -72.23, -81.8, -80.86, -96.63, -48.4, -72.85, 46.09, -56.52, -93.05, -54.32, -80.61, -80.61, -79.27, -107.36, -54.84, -92.19, -55.14, -78.13, -60, -68.93, -108.75, -73.31 ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#savefiles:
    # i the output of two cities file, from the originally generated file and the list with the replaced "+" character
    
import csv

with open("output_data/original_cities.csv", "w", newline = "") as citiesoriginal:
    writer_1 = csv.writer(citiesoriginal)
    for city in cities:    
        writer_1.writerow([city])

# %%
with open("output_data/fixed_cities.csv", "w", newline = "") as citiesfixed:
    writer_2 = csv.writer(citiesfixed)
    for city_2 in cities_2:
        writer_2.writerow([city_2])

# %%
weather_dict = {
    "city": city_name,
    "latitude": latitude,
    "longitude": longitude,
    "time dt": time,
    "timezone": timezone,
    "temperature": temperature,
    "humidity_perc": humidity_perc,
    "cloudiness_perc": cloudiness_perc,
    "wind_speed": wind_speed,
}
    

weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#            city latitude longitude     time dt timezone temperature  \
# 0     sept-iles     50.2    -66.38  1561419902     6.93       59.32
# 1   pangnirtung    66.15    -65.72  1561419886     6.53       55.66
# 2  saint+george    39.45     22.34  1561420017     9.17       74.59
# 3         coari    -4.09    -63.14  1561420018     2.51       77.44
# 4        castro   -42.48    -73.76  1561419774     5.82        39.2
#
#   humidity_perc cloudiness_perc wind_speed
# 0            48              20       6.93
# 1            38              73       6.53
# 2            69              75       9.17
# 3            78              39       2.51
# 4            93              40       5.82

# %%
weather_data.to_csv('output_data/weather_data.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
